# %% [markdown]
# ## Preprocessament d'imatges

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.image import resize
import cv2
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

# %%
def crop_image_from_gray(img,tol=7):
    if img.ndim ==2:
        mask = img>tol
        return img[np.ix_(mask.any(1),mask.any(0))]
    elif img.ndim==3:
        gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        mask = gray_img>tol
        
        check_shape = img[:,:,0][np.ix_(mask.any(1),mask.any(0))].shape[0]
        if (check_shape == 0): 
            return img
        else:
            img1=img[:,:,0][np.ix_(mask.any(1),mask.any(0))]
            img2=img[:,:,1][np.ix_(mask.any(1),mask.any(0))]
            img3=img[:,:,2][np.ix_(mask.any(1),mask.any(0))]
            img = np.stack([img1,img2,img3],axis=-1)
        return img

# %%
def gauss_circle(img):
    #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = crop_image_from_gray(img)
     #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    height, width, depth = img.shape    
    
    x = int(width/2)
    y = int(height/2)
    r = np.amin((x,y))
    
    circle_img = np.zeros((height, width), np.uint8)
    cv2.circle(circle_img, (x,y), int(r), 1, thickness=-1)
    img = cv2.bitwise_and(img, img, mask=circle_img)
    img = crop_image_from_gray(img)
    img=cv2.addWeighted ( img,4, cv2.GaussianBlur( img , (0,0) , sigmaX= 30) ,-4 ,128)
    img = cv2.resize(img,(256,256))
    return img

# %%
def save_image(img_preprocessed, save_path):
    # Asegurar que img_preprocessed está en el rango correcto [0, 255] y es de tipo uint8
    img_preprocessed_clipped = np.clip(img_preprocessed, 0, 255)
    img_preprocessed_uint8 = img_preprocessed_clipped.astype(np.uint8)

    # Guardar la imagen
    cv2.imwrite(save_path, cv2.cvtColor(img_preprocessed_uint8, cv2.COLOR_RGB2BGR))

# %%
img_path= 'train/0/10_left.jpeg'
img = load_img(img_path)

plt.imshow(img)

# %%
img_array = img_to_array(img)  # Conversión a array de NumPy

# Procesa la imagen con gauss_circle
img_preprocessed = gauss_circle(img_array)

# Guarda la imagen procesada en el disco
save_path = 'train/0/10_left_processed.jpeg'
save_image(img_preprocessed, save_path)

# Para visualizar la imagen procesada, cárgala desde el disco
img_processed_loaded = cv2.imread(save_path)
img_processed_loaded = cv2.cvtColor(img_processed_loaded, cv2.COLOR_BGR2RGB)  # Convierte de BGR a RGB para visualizar correctamente

plt.imshow(img_processed_loaded)
plt.show()

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np

# Supongamos que ya tienes definidas las funciones 'gauss_circle' y 'crop_image_from_gray'

# Cargar la imagen (Asegúrate de reemplazar 'path_to_your_image' con la ruta real de tu imagen)
img = load_img(img_path)

# Convertir la imagen PIL a un array de NumPy
img_array = img_to_array(img)

# Ahora, procesa esta imagen con la función 'gauss_circle'
img_preprocessed = gauss_circle(img_array)

# Asegúrate de que img_preprocessed es un array de NumPy adecuado para plt.imshow.
# Si 'gauss_circle' ya devuelve un array de NumPy en el rango [0, 255] y tipo de dato uint8, esto debería funcionar directamente:
if isinstance(img_preprocessed, np.ndarray) and img_preprocessed.dtype == np.uint8:
    plt.imshow(img_preprocessed)
    plt.show()
else:
    # Si img_preprocessed no es un array de uint8, es posible que necesites convertirlo.
    # Esto depende de cómo 'gauss_circle' maneja la imagen.
    print("Revisa el tipo de dato y el rango de img_preprocessed.")
# Out:
# Revisa el tipo de dato y el rango de img_preprocessed.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Ajustar los valores de la imagen para asegurar que estén en el rango [0, 255]
img_preprocessed_clipped = np.clip(img_preprocessed, 0, 255)

# Convertir a uint8
img_preprocessed_uint8 = img_preprocessed_clipped.astype(np.uint8)

# Ahora puedes visualizar la imagen
plt.imshow(img_preprocessed_uint8)
plt.show()

# %%
def preprocess_and_save(image_path, save_path):
    # Cargar imagen original con TensorFlow/Keras
    img = load_img(image_path)  # Esto carga la imagen como un objeto PIL Image
    
    # Convertir de PIL Image a array de numpy
    img_array = img_to_array(img)
    
    # Aplicar la función gauss_circle para el procesamiento de imágenes
    # gauss_circle ya redimensiona la imagen a 256x256
    img_processed = gauss_circle(img_array)
    save_image(img_processed, save_path)
    #return img_processed

# %%
new_image= preprocess_and_save(img_path, '10_left_processed.jpeg')

# %%
# Cargar la imagen procesada desde el disco
img_processed = cv2.imread('10_left_processed.jpeg')

# Convertir la imagen de BGR (OpenCV usa BGR por defecto) a RGB
img_processed_rgb = cv2.cvtColor(img_processed, cv2.COLOR_BGR2RGB)

# Mostrar la imagen con matplotlib
plt.imshow(img_processed_rgb)
plt.axis('off')  # Opcional: eliminar los ejes
plt.show()

# %%
from vit_keras import utils

# Mostrar la imagen con matplotlib
img_processed = utils.read('10_left_processed.jpeg',256)
plt.imshow(img_processed_rgb)

plt.axis('off')  # Opcional: eliminar los ejes
plt.show()

# %% [markdown]
# ## Aplicar la funció preprocess_and_save per a generar un nou conjut de dades preprocessades a Preprocessed_dataset

# %%
import os
from pathlib import Path
from tqdm import tqdm

# Asegúrate de tener las funciones necesarias definidas o importadas, incluida preprocess_and_save

def preprocess_and_save_images_in_folder(source_folder, destination_folder):
    """
    Procesa y guarda las imágenes de todas las subcarpetas encontradas en source_folder,
    manteniendo la estructura de subcarpetas en destination_folder.
    """
    # Crear la carpeta de destino si no existe
    Path(destination_folder).mkdir(parents=True, exist_ok=True)
    
    # Buscar subcarpetas en la carpeta de origen
    subfolders = [f.path for f in os.scandir(source_folder) if f.is_dir()]
    
    for subfolder in subfolders:
        subfolder_name = os.path.basename(subfolder)
        destination_subfolder = os.path.join(destination_folder, subfolder_name)
        
        # Crear subcarpeta de destino si no existe
        Path(destination_subfolder).mkdir(parents=True, exist_ok=True)
        
        # Procesar y guardar imágenes de la subcarpeta actual
        file_names = os.listdir(subfolder)
        for file_name in tqdm(file_names, desc=f"Processing {subfolder_name}"):
            source_path = os.path.join(subfolder, file_name)
            destination_path = os.path.join(destination_subfolder, file_name)
            
            # Aplicar la función de preprocesamiento y guardar la imagen
            preprocess_and_save(source_path, destination_path)

# Ejemplo de uso
source_folder = 'test_original'
destination_folder = 'test_preprocessed'
preprocess_and_save_images_in_folder(source_folder, destination_folder)
# Out:
# Processing DR: 100%|█████████████████████████████████████████████████████████████████| 113/113 [00:02<00:00, 54.68it/s]
# Processing No_DR: 100%|██████████████████████████████████████████████████████████████| 118/118 [00:02<00:00, 56.06it/s]

# %% [markdown]
# ## Generar els tres conjunts de dades

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Define los porcentajes para la división de los datos
train_size = 0.7
val_size = 0.2
test_size = 0.1

# Verifica que los porcentajes sumen 1 (o 100%)
#assert train_size + val_size + test_size == 1

# Función para dividir los datos y copiar los archivos
def split_data(source_dir, train_dir, val_dir, test_dir):
    # Crea las carpetas para los conjuntos de datos si no existen
    for folder in [train_dir, val_dir, test_dir]:
        os.makedirs(folder, exist_ok=True)
        # Crear carpetas para las clases específicas "DR" y "No_DR"
        os.makedirs(os.path.join(folder, "DR"), exist_ok=True)
        os.makedirs(os.path.join(folder, "No_DR"), exist_ok=True)

    # Iterar sobre cada subcarpeta de clase y dividir los archivos
    for class_name in ["DR", "No_DR"]:  # Especificar directamente las clases
        class_dir = os.path.join(source_dir, class_name)
        images = os.listdir(class_dir)

        # Usamos train_test_split dos veces para dividir en train, val y test
        train_images, temp_images = train_test_split(images, train_size=train_size, random_state=42)
        val_images, test_images = train_test_split(temp_images, train_size=val_size / (val_size + test_size), random_state=42)

        # Función auxiliar para copiar los archivos
        def copy_files(files, destination):
            for f in files:
                shutil.copy(os.path.join(class_dir, f), os.path.join(destination, class_name, f))

        # Copiar los archivos a las respectivas carpetas
        copy_files(train_images, train_dir)
        copy_files(val_images, val_dir)
        copy_files(test_images, test_dir)

# Llamada a la función split_data con las rutas apropiadas
preprocessed_dataset_dir = 'Preprocessed_Dataset'
train_dir = 'train'
val_dir = 'val'
test_dir = 'test'

split_data(preprocessed_dataset_dir, train_dir, val_dir, test_dir)

# %% [markdown]
# ## Augmentació de dades en les carpetes de les classes menys representades

# %%
import os
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tqdm import tqdm

def augment_folder_images(source_folder, dest_folder, num_augmented_images, prefix):
    # Crea el ImageDataGenerator con las transformaciones deseadas
    datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        fill_mode='nearest'
    )

    # Lista todas las imágenes en la carpeta de origen
    image_files = os.listdir(source_folder)

    # Crea la carpeta de destino si no existe
    os.makedirs(dest_folder, exist_ok=True)

    # Itera sobre todas las imágenes en la carpeta de origen
    for image_name in tqdm(image_files, desc='Aumentando imágenes'):
        # Carga la imagen y la convierte en un array
        image_path = os.path.join(source_folder, image_name)
        image = load_img(image_path)
        image_array = img_to_array(image)
        image_array = image_array.reshape((1,) + image_array.shape)

        # Copiar la imagen original al directorio de destino
        shutil.copy(image_path, dest_folder)

        # Preparar el nombre del archivo sin la extensión
        file_name, file_extension = os.path.splitext(image_name)
        
        # Crear las imágenes aumentadas
        i = 0
        for batch in datagen.flow(image_array, batch_size=1,
                                  save_to_dir=dest_folder,
                                  save_prefix=prefix + file_name,
                                  save_format='jpeg'):
            i += 1
            if i >= num_augmented_images:
                break  # Detener el bucle después de generar el número deseado de imágenes aumentadas

# Uso de la función
source_folder = 'train/DR'  # Por ejemplo, la clase '0'
dest_folder = 'train_augmented/DR'  # Destino donde guardar las imágenes aumentadas
num_augmented_images = 1  # Número deseado de imágenes aumentadas por cada imagen original
prefix = 'aug'  # Prefijo para las imágenes aumentadas

augment_folder_images(source_folder, dest_folder, num_augmented_images, prefix)
# Out:
# Aumentando imágenes: 100%|█████████████████████████████████████████████████████████| 6514/6514 [02:23<00:00, 45.46it/s]

# %% [markdown]
# ## Fer subsampling

# %%
import os
import shutil
import random

# Fija la semilla del generador de números aleatorios para reproducibilidad
random.seed(42)

def move_random_files(source_folder, destination_folder, n):
    """
    Mueve N archivos seleccionados aleatoriamente de source_folder a destination_folder.

    :param source_folder: Carpeta de origen de los archivos.
    :param destination_folder: Carpeta de destino de los archivos.
    :param n: Número de archivos a mover.
    """
    # Lista todos los archivos en la carpeta de origen
    files = [f for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]
    
    # Selecciona aleatoriamente N archivos
    selected_files = random.sample(files, min(n, len(files)))
    
    # Mueve cada archivo seleccionado a la carpeta de destino
    for file in selected_files:
        shutil.move(os.path.join(source_folder, file), os.path.join(destination_folder, file))
        print(f"Archivo {file} movido a {destination_folder}")

# Parámetros de ejemplo, reemplázalos por tus rutas reales
source_folder = 'Preprocessed_Dataset/No_DR'
destination_folder = 'Preprocessed_Dataset/No_DR_subsampled'
n = 9306  # Número de archivos a mover

# Llama a la función
move_random_files(source_folder, destination_folder, n)
# Out:
# Archivo 42343_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 15674_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 11298_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 7668_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 24059_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 22511_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 2134_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 17133_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 7404_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 15230_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 44225_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 7616_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 37666_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 14446_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 39898_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 31424_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 11640_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 11543_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 14784_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 21109_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 21854_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 35684_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 40476_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 11366_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 38495_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 2008_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 6412_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 42925_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 563_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 37645_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 31275_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 21196_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 32905_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 39827_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 24207_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 10333_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 8526_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 18099_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 5467_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 31462_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 27194_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 241_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 17922_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 20982_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 8779_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 2701_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 15217_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 14750_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 29246_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 14940_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 28173_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 27381_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 40576_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 23477_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 12292_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 7075_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 33394_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 37266_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 16398_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 29166_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 14039_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 38048_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 24949_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 41832_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 41289_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 28287_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 39281_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 19745_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 5803_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 13609_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 1242_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 43470_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 21609_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 9269_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 24777_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 14091_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 21857_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 15151_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 29267_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 24201_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 33110_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 42155_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 28461_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 18245_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 2874_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 27979_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 2063_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 43934_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 23628_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 5664_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 4659_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 42826_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 13691_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 40841_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 42130_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 18644_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 37177_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 7048_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 22509_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 18293_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 33555_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 29217_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 23797_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 42377_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 4914_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 38287_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 21167_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 4727_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 26434_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 9010_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 9428_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 12946_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 21651_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 1165_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 26013_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 30284_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 23669_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 13438_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 20748_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 38767_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 6473_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 25990_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 20836_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 43194_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 35383_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 3001_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 42530_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 33375_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 17289_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 23508_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 17134_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 22598_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 7832_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 38501_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 37406_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 23381_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 7943_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 39612_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 31790_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 39565_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 30182_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 2830_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 2113_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 1706_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 35891_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 35080_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 14653_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 8395_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 12488_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 15588_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 17798_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 41776_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 1810_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 448_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 31439_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 40219_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 13304_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 29524_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 29335_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 40187_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 33810_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 36930_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 22837_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 38126_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 10583_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 4482_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 6594_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 15847_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 4550_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 37309_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 8121_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 23615_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 9020_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 4242_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 27188_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 15692_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 24971_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 32102_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 18040_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 33124_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 10166_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 6678_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 6550_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 23412_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 35453_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 8664_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 19011_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 35802_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 15426_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 41668_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 25171_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 42321_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 969_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 40838_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 20092_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 9755_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 2893_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 8706_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 18191_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 37420_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 9589_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 36987_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 10028_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 40345_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 2642_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 34857_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 10989_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 1569_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 28356_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 25658_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 22222_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 13033_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 2228_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 38778_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 14036_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 14388_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 7187_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 34704_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 13595_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 8619_left.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo 3710_right.jpeg movido a Preprocessed_Dataset/No_DR_subsampled
# Archivo